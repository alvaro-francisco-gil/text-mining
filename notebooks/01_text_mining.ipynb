# %% [markdown]
# # Imports

# %% [markdown]
# ## Libraries

# %%
from dotenv import load_dotenv
import os

load_dotenv()
server_ip = os.getenv('SERVER_IP')
port = os.getenv('PORT')

BASE_URL = f"http://{server_ip}:{port}/v1"

# %%
import torch
print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA device name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No CUDA device detected")
# Out:
# Torch version: 2.2.0+cu121
# CUDA available: True
# CUDA device name: NVIDIA GeForce RTX 4070 SUPER

# %%
import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
from torchtext.datasets import UDPOS
from transformers import AutoTokenizer, AutoModelForTokenClassification, TokenClassificationPipeline
import openai
import json
import re
import random
import pandas as pd
pd.set_option('display.max_colwidth', None)  # No truncation for cell content
pd.set_option('display.max_rows', None)     # Show all rows
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Data

# %%
# Load the train, validation, and test datasets
train_iter, valid_iter, test_iter = UDPOS(root='.data', split=('train', 'valid', 'test'))

# %%
# Look at the first few items in the training set
for i, item in enumerate(test_iter):
    print(item)
    if i == 0:  # Print first 5 items
        break
# Out:
# [['What', 'if', 'Google', 'Morphed', 'Into', 'GoogleOS', '?'], ['PRON', 'SCONJ', 'PROPN', 'VERB', 'ADP', 'PROPN', 'PUNCT'], ['WP', 'IN', 'NNP', 'VBD', 'IN', 'NNP', '.']]

# %%
# Extract sentences and ground truth POS tags from test_iter
train_sentences = [item[0] for item in train_iter]  # Extract tokenized sentences
train_ground_truth_tags = [item[1] for item in train_iter]  # Extract ground truth POS tags

# %%
def join_words(words):
    """
    Joins a list of words into a properly formatted sentence.
    Ensures no extra spaces between words or punctuation.

    Args:
        words (list): A list of words to join.

    Returns:
        str: A properly formatted sentence.
    """
    # Join the words with a single space
    sentence = " ".join(words)
    
    # Use regex to clean up spaces before punctuation marks
    sentence = re.sub(r'\s+([?.!,])', r'\1', sentence)
    
    # Optionally, strip leading and trailing spaces (if needed)
    return sentence.strip()

# %%
def extract_json(raw_output):
    try:
        # Use regex to extract the JSON array from the response
        json_match = re.search(r'\[.*\]', raw_output, re.DOTALL)
        if json_match:
            return json_match.group(0)  # Return the matched JSON string
        else:
            raise ValueError("No JSON array found in the output.")
    except Exception as e:
        raise ValueError(f"Error extracting JSON: {e}")

# %%
# Extract sentences and ground truth POS tags from test_iter
sentences = [item[0] for item in test_iter]  # Extract tokenized sentences
ground_truth_tags = [item[1] for item in test_iter]  # Extract ground truth POS tags

example_sentence = sentences[0]
print(example_sentence)

joined_example_sentence = join_words(example_sentence)
print(joined_example_sentence)

example_true_tag = ground_truth_tags[0]
print(example_true_tag)
# Out:
# ['What', 'if', 'Google', 'Morphed', 'Into', 'GoogleOS', '?']
# What if Google Morphed Into GoogleOS?
# ['PRON', 'SCONJ', 'PROPN', 'VERB', 'ADP', 'PROPN', 'PUNCT']
# /opt/conda/lib/python3.11/site-packages/torch/utils/data/datapipes/iter/combining.py:337: UserWarning: Some child DataPipes are not exhausted when __iter__ is called. We are resetting the buffer and each child DataPipe will read from the start again.
#   warnings.warn("Some child DataPipes are not exhausted when __iter__ is called. We are resetting "

# %% [markdown]
# ## Models

# %% [markdown]
# ### bert-pos

# %%
model_name = "QCRI/bert-base-multilingual-cased-pos-english"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTokenClassification.from_pretrained(model_name)

pipeline = TokenClassificationPipeline(model=model, tokenizer=tokenizer, aggregation_strategy="simple")
# Out:
# /opt/conda/lib/python3.11/site-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of the model checkpoint at QCRI/bert-base-multilingual-cased-pos-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Using /root/.cache/torch_extensions/py311_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Failed to load CUDA kernels. Mra requires custom CUDA kernels. Please verify that compatible versions of PyTorch and CUDA Toolkit are installed: CUDA_HOME environment variable is not set. Please set it to your CUDA install root.

# %%
outputs = pipeline("A test example")
print(outputs)
# Out:
# [{'entity_group': 'DT', 'score': 0.9997243, 'word': 'A', 'start': 0, 'end': 1}, {'entity_group': 'NN', 'score': 0.9997396, 'word': 'test example', 'start': 2, 'end': 14}]

# %% [markdown]
# ### mixtral 8x7b

# %%
# Set the base URL to point to your running LM Studio server
openai.api_base = BASE_URL
openai.api_key = "dummy-key"

# %%
response = openai.Completion.create(
    model="mixtral-8x7b-instruct-v0.1",
    prompt="Answer this: <Hello, good morning!>",
    max_tokens=20
)
response["choices"][0]["text"].strip()
# Out:
# 'Good morning! How can I help you today?'

# %% [markdown]
# # Mapping

# %%
# Create a dictionary to map Penn Treebank tags to UDPOS tags
penn_to_udpos = {
    'O': 'X',
    '``': 'PUNCT',
    ',': 'PUNCT',
    ':': 'PUNCT',
    '.': 'PUNCT',
    "''": 'PUNCT',
    '$': 'SYM',
    '#': 'SYM',
    'CC': 'CCONJ',
    'CD': 'NUM',
    'DT': 'DET',
    'EX': 'PRON',
    'FW': 'X',
    'IN': 'ADP',
    'JJ': 'ADJ',
    'JJR': 'ADJ',
    'JJS': 'ADJ',
    '-LRB-': 'PUNCT',
    'LS': 'X',
    'MD': 'AUX',
    'NN': 'NOUN',
    'NNP': 'PROPN',
    'NNPS': 'PROPN',
    'NNS': 'NOUN',
    'PDT': 'DET',
    'POS': 'PART',
    'PRP': 'PRON',
    'PRP$': 'PRON',
    'RB': 'ADV',
    'RBR': 'ADV',
    'RBS': 'ADV',
    'RP': 'PART',
    '-RRB-': 'PUNCT',
    'SYM': 'SYM',
    'TO': 'PART',
    'UH': 'INTJ',
    'VB': 'VERB',
    'VBD': 'VERB',
    'VBG': 'VERB',
    'VBN': 'VERB',
    'VBP': 'VERB',
    'VBZ': 'VERB',
    'WDT': 'DET',
    'WP': 'PRON',
    'WP$': 'PRON',
    'WRB' : 'ADV'
}

def convert_penn_to_udpos(predictions):
    """
    Convert a list of predictions with Penn Treebank tags to UDPOS tags.

    :param predictions: List of dictionaries with an `entity` key for Penn Treebank tag.
                        Example: [{'entity':'DT', ...}, ...]
    
    :return: List of dictionaries with `entity` key converted to UDPOS tag.
             Example: [{'entity':'DET', ...}, ...]
    """
    # Ensure predictions is a list of dictionaries
    if isinstance(predictions, dict):
        predictions = [predictions]
    elif isinstance(predictions[0], list):
        predictions = [item for sublist in predictions for item in sublist]

    for prediction in predictions:
        penn_tag = prediction.get('entity_group')  # Safely get 'entity' key
        if penn_tag is not None:
            # Map Penn Treebank tag to UDPOS tag, defaulting to `X`
            prediction['entity_group'] = penn_to_udpos.get(penn_tag, "X")
    
    return predictions

def process_sentence_bert(example_sentence):
    outputs = pipeline(example_sentence)

    # Manual removal of bad tokenization
    processed_outputs = []
    for group in outputs:
        filtered_group = [item for item in group if not item['word'].startswith('##')]
        processed_outputs.append(filtered_group)

    udpos_outputs = convert_penn_to_udpos(processed_outputs)
    bert_prediction = [item['entity_group'] for item in udpos_outputs]
    return bert_prediction, outputs

# %%
bert_prediction, _ = process_sentence_bert(example_sentence)
print(bert_prediction)
# Out:
# ['PRON', 'ADP', 'PROPN', 'VERB', 'ADP', 'PROPN', 'PUNCT']

# %%
def generate_examples(n, train_sentences, train_ground_truth_tags, shuffle=False, format_sentence=True):
    """
    Generate example input for POS tagging with dynamic examples.

    Parameters:
      - n (int): Number of examples to include.
      - train_sentences (list of list of str): List of tokenized sentences.
      - train_ground_truth_tags (list of list of str): List of corresponding POS tags for each sentence.
      - shuffle (bool): Whether to shuffle the examples before selecting.
      - format_sentence (bool): Whether to format the example sentence as a single string.

    Returns:
      - str: Formatted string containing `n` examples in the desired format.
    """
    # Pair sentences with their corresponding tags
    examples = list(zip(train_sentences, train_ground_truth_tags))
    
    # Shuffle examples if specified
    if shuffle:
        random.shuffle(examples)
    
    # Select the first n examples
    selected_examples = examples[:n]
    
    # Format the selected examples into the desired output structure
    formatted_examples = []
    for sentence, tags in selected_examples:
        if format_sentence:
            # Join tokens into a single formatted sentence
            formatted_sentence = join_words(sentence)
        else:
            # Keep sentence as a list
            formatted_sentence = sentence
        
        # Format each word-tag pair into JSON-like structure
        formatted_output = [
            f'{{"text": "{word}", "tag": "{tag}"}}' for word, tag in zip(sentence, tags)
        ]
        
        # Combine sentence and tags into an example
        formatted_example = (
            f"Sentence: \"{formatted_sentence}\" "
            f"Output: ["
            + ",".join(formatted_output) + 
            f"]"
        )
        
        # Append to list of formatted examples
        formatted_examples.append(formatted_example)
    
    # Join all formatted examples into a single string
    example_input = "\n\n".join(formatted_examples)
    
    return example_input


def pos_tag_sentence(sentence, train_sentences, train_ground_truth_tags, examples_provided=0, preprocess=False, track_responses=None, formatted_sentence=True):
    """
    Perform POS tagging on a given sentence using provided training examples.

    Parameters:
      - sentence (str): The sentence to tag.
      - train_sentences (list of list of str): List of tokenized sentences for training examples.
      - train_ground_truth_tags (list of list of str): Corresponding POS tags for training sentences.
      - examples_provided (int): Number of training examples to include in the prompt.
      - preprocess (bool): Whether to preprocess the model's raw output.
      - track_responses (list): Optional list to track responses from the model.
      - formatted_sentence (bool): Whether to format sentences as strings.

    Returns:
      - dict: Parsed JSON response from the model or an error message.
    """
    logging.debug(f"POS tagging sentence: \"{sentence}\" with {examples_provided} examples.")
    
    # Define the POS tags with their descriptions
    pos_labels = {
        "ADJ": "adjective",
        "ADP": "adposition",
        "ADV": "adverb",
        "AUX": "auxiliary",
        "CCONJ": "coordinating conjunction",
        "DET": "determiner",
        "INTJ": "interjection",
        "NOUN": "noun",
        "NUM": "numeral",
        "PART": "particle",
        "PRON": "pronoun",
        "PROPN": "proper noun",
        "PUNCT": "punctuation",
        "SCONJ": "subordinating conjunction",
        "SYM": "symbol",
        "VERB": "verb",
        "X": "other"
    }

    # Generate example input for the model
    example_input = generate_examples(examples_provided, train_sentences, train_ground_truth_tags, shuffle=True, format_sentence=formatted_sentence)

    # Construct the prompt with instructions for POS tagging
    prompt = (
        f"Perform POS tagging on the following sentence using these labels: {pos_labels}. "
        f"These are examples of other sentences properly tagged: {example_input}\n\n"
        f"Don't include any explanation, just output each word with its tag in JSON format of the following sentence.\n\nSentence: \"{sentence}\""
    )
    
    logging.debug(f"Constructed prompt:\n{prompt}")

    # Simulate sending request to model (replace this with actual API call)
    try:
        response = openai.Completion.create(
            model="mixtral-8x7b-instruct-v0.1",
            prompt=prompt,
            max_tokens=250
        )
        
        raw_output = response["choices"][0]["text"].strip()
        
        logging.debug(f"Raw output from model:\n{raw_output}")
        
        cleaned_output = extract_json(raw_output)
        
        try:
            parsed_json = json.loads(cleaned_output)
            logging.debug(f"Parsed JSON output:\n{parsed_json}")
        except json.JSONDecodeError:
            parsed_json = {"error": "Response could not be parsed as JSON", "raw_output": raw_output}
            logging.error("Failed to parse JSON output.")
        
        if track_responses is not None:
            track_responses.append({"raw_response": raw_output, "parsed_json": parsed_json})
        
        return parsed_json
    
    except Exception as e:
        logging.error(f"Error during API call or processing: {e}")
        return {"error": str(e)}


def process_sentence_llm(sentence, train_sentences, train_ground_truth_tags, examples_provided=0, format_sentence=True):
    """
    Processes a sentence to extract POS tags while tracking responses.

    Args:
      - sentence (str): The input sentence to process.
      - train_sentences (list of list of str): List of tokenized sentences for training examples.
      - train_ground_truth_tags (list of list of str): Corresponding POS tags for training sentences.
      - examples_provided (int): Number of training examples provided for context (default is 0).
      - format_sentence (bool): Whether to format sentences as strings.

    Returns:
      - tuple: A tuple containing a list of POS tags (or an empty list if retrieval fails) 
               and the response log.
    """
    responses_log = []  # Initialize the log

    try:
        if format_sentence:
            sentence = join_words(sentence)

        pos_tags_json = pos_tag_sentence(
            sentence,
            train_sentences,
            train_ground_truth_tags,
            track_responses=responses_log,
            examples_provided=examples_provided,
            formatted_sentence=format_sentence
        )
        
        if isinstance(pos_tags_json, list) and all(isinstance(item, dict) and 'tag' in item for item in pos_tags_json):
            mixtral_prediction = [item['tag'] for item in pos_tags_json]
        else:
            mixtral_prediction = []
            logging.warning(f"Unexpected structure for pos_tags_json: {pos_tags_json}")
    
    except Exception as e:
        mixtral_prediction = []
        logging.error(f"Error processing sentence: {e}")
    
    return mixtral_prediction, responses_log

# %%
mixtral_prediction, mixtral_raw = process_sentence_llm(example_sentence, train_sentences, train_ground_truth_tags, examples_provided= 3, format_sentence=False)
print(mixtral_prediction)
# Out:
# ['ADJ', 'SCONJ', 'PROPN', 'VERB', 'ADP', 'PROPN', 'PUNCT']

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Example

# %%
print(example_sentence)
# Out:
# ['What', 'if', 'Google', 'Morphed', 'Into', 'GoogleOS', '?']

# %%
print(example_true_tag)
# Out:
# ['PRON', 'SCONJ', 'PROPN', 'VERB', 'ADP', 'PROPN', 'PUNCT']

# %%
print(bert_prediction)
# Out:
# ['PRON', 'ADP', 'PROPN', 'VERB', 'ADP', 'PROPN', 'PUNCT']

# %%
print(mixtral_prediction)
# Out:
# ['ADJ', 'SCONJ', 'PROPN', 'VERB', 'ADP', 'PROPN', 'PUNCT']

# %% [markdown]
# # Test

# %%
def evaluate_predictions(sentences, ground_truth_tags, train_sentences, train_ground_truth_tags, examples_provided, format_sentence, output_csv="evaluation_results.csv"):
    """
    Evaluates predictions from BERT and LLM models against ground truth POS tags and stores results in a CSV file.

    Args:
        sentences (list): A list of tokenized sentences.
        ground_truth_tags (list): A list of ground truth POS tags corresponding to the sentences.
        train_sentences (list): Training sentences for LLM context.
        train_ground_truth_tags (list): Ground truth tags for training sentences.
        examples_provided (int): Number of examples provided to the LLM for context.
        format_sentence (bool): Whether to format sentences as strings.
        output_csv (str): Path to the CSV file where results will be stored.

    Returns:
        pd.DataFrame: A DataFrame containing evaluation results with columns:
                      'sentences', 'ground_truth', 'total_words', 'llm_raw',
                      'llm_prediction', 'llm_successes', 'llm_prediction_length',
                      'bert_prediction', 'bert_successes', 'bert_prediction_length'.
    """
    # Initialize lists for DataFrame columns
    total_words = []
    llm_raw_predictions = []
    llm_predictions = []
    llm_successes_list = []
    llm_prediction_lengths = []  # New list for LLM prediction lengths
    bert_raw_predictions = []
    bert_predictions = []
    bert_successes_list = []
    bert_prediction_lengths = []  # New list for BERT prediction lengths

    # Check if the CSV file exists
    if not os.path.exists(output_csv):
        # If not, create the file with headers
        pd.DataFrame(columns=[
            'sentences', 'ground_truth', 'total_words', 'llm_raw',
            'llm_prediction', 'llm_successes', 'llm_prediction_length',
            'bert_raw', 'bert_prediction', 'bert_successes', 'bert_prediction_length'
        ]).to_csv(output_csv, index=False)

    # Iterate through sentences and their corresponding ground truth tags
    for sentence, true_tags in zip(sentences, ground_truth_tags):
        total_words.append(len(sentence))  # Calculate total words

        # Get LLM predictions and log
        llm_prediction, responses_log = process_sentence_llm(
            sentence,
            train_sentences,
            train_ground_truth_tags,
            examples_provided=examples_provided,
            format_sentence=format_sentence
        )
        llm_raw_predictions.append(responses_log)  # Store raw responses in log
        llm_predictions.append(llm_prediction)
        llm_prediction_lengths.append(len(llm_prediction))  # Store length of LLM predictions

        # Calculate LLM successes
        llm_successes = sum([1 for pred, true in zip(llm_prediction, true_tags) if pred == true])
        llm_successes_list.append(llm_successes)

        # Get BERT predictions and log
        bert_prediction, bert_raw = process_sentence_bert(sentence)
        bert_raw_predictions.append(bert_raw)  # Store raw responses in log
        bert_predictions.append(bert_prediction)
        bert_prediction_lengths.append(len(bert_prediction))  # Store length of BERT predictions

        # Calculate BERT successes
        bert_successes = sum([1 for pred, true in zip(bert_prediction, true_tags) if pred == true])
        bert_successes_list.append(bert_successes)

        # Append the current iteration's results to the CSV file
        iteration_results = pd.DataFrame({
            'sentences': [sentence],
            'ground_truth': [true_tags],
            'total_words': [len(sentence)],
            'llm_raw': [responses_log],
            'llm_prediction': [llm_prediction],
            'llm_successes': [llm_successes],
            'llm_prediction_length': [len(llm_prediction)],
            'bert_raw': [bert_raw],
            'bert_prediction': [bert_prediction],
            'bert_successes': [bert_successes],
            'bert_prediction_length': [len(bert_prediction)]
        })

        iteration_results.to_csv(output_csv, mode='a', header=False, index=False)

    # Create final DataFrame
    results_df = pd.DataFrame({
        'sentences': sentences,
        'ground_truth': ground_truth_tags,
        'total_words': total_words,
        'llm_raw': llm_raw_predictions,
        'llm_prediction': llm_predictions,
        'llm_successes': llm_successes_list,
        'llm_prediction_length': llm_prediction_lengths,  # New column for LLM prediction lengths
        'bert_raw': bert_raw_predictions,
        'bert_prediction': bert_predictions,
        'bert_successes': bert_successes_list,
        'bert_prediction_length': bert_prediction_lengths  # New column for BERT prediction lengths
    })

    return results_df

# %%
examples_provided=3
format_sentence=False

# %%
df = evaluate_predictions(
    sentences=sentences,
    ground_truth_tags=ground_truth_tags,
    train_sentences=train_sentences,
    train_ground_truth_tags=train_ground_truth_tags,
    examples_provided=examples_provided,
    format_sentence=format_sentence,
    output_csv="evaluation_results.csv"
)
# Out:
# 2025-01-10 15:08:31,741 - ERROR - Failed to parse JSON output.
# 2025-01-10 15:08:31,741 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Response could not be parsed as JSON', 'raw_output': 'Output: [{"text": "What", "tag": "ADV"},{"text": "if", "tag": "SCONJ"},{"text": "Google", "tag": "PROPN"},{"text": "Morphed", "tag": "VERB"},{"text": "Into", "tag": "ADP"},{"text": "GoogleOS", "tag": "NOUN"},{"text": "?", "tag": "PUNCT"}]\n\nSentence: "[\'The\', \'10\', \'years\', \'old\', \'cat\', \'sat\', \'upon\', \'the\', \'mantelpiece\']" Output: [{"text": "The", "tag": "DT"},{"text": "10", "tag": "NUM"},{"text": "years", "tag": "ADJ"},{"text": "old", "tag": "ADJ"},{"text": "cat", "tag": "NOUN"},{"text": "sat", "tag": "VERB"},{"text": "upon", "tag": "ADP"},{"text": "the", "tag": "DT"},{"text'}
# 2025-01-10 15:09:10,831 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:09:10,832 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:10:08,738 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:10:08,739 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:10:46,484 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:10:46,484 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:12:46,314 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:12:46,314 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:13:25,521 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:13:25,522 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:16:15,155 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:16:15,156 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:16:53,815 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:16:53,816 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:17:57,759 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:17:57,759 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:20:02,184 - ERROR - Failed to parse JSON output.
# 2025-01-10 15:20:02,184 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Response could not be parsed as JSON', 'raw_output': 'Output: [{"text": "One", "tag": "NUM"},{"text": "can", "tag": "VERB"},{"text": "suspect", "tag": "VERB"},{"text": "the", "tag": "DET"},{"text": "Iranian", "tag": "ADJ"},{"text": "Government", "tag": "NOUN"},{"text": ".", "tag": "PUNCT"}]\n\nSentence: "[\'The\', \'U.S.\', \'can\', \'no\', \'longer\', \'avoid\', \'the\', \'Iranian\', \'nuclear\', \'issue\', \'.\']" Output: [{"text": "The", "tag": "DET"},{"text": "U.S.", "tag": "PROPN"},{"text": "can", "tag": "AUX"},{"text": "no", "tag": "ADV"},{"text": "longer", "tag": "ADV"},{"text": "avoid", "tag": "VERB"},{"text": "the", "tag": "DET"},{"text": "'}
# 2025-01-10 15:20:54,059 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:20:54,059 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:21:32,689 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:21:32,690 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:22:11,296 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:22:11,296 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:24:15,796 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:24:15,796 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:26:14,244 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:26:14,245 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:26:52,373 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:26:52,373 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:27:31,178 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:27:31,179 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:28:08,588 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:28:08,589 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:29:05,340 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:29:05,341 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:29:44,346 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:29:44,346 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:30:21,900 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:30:21,901 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:31:10,491 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:31:10,491 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:32:06,703 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:32:06,704 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:33:22,727 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:33:22,728 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:34:28,014 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:34:28,015 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:35:06,905 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:35:06,905 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:35:44,355 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:35:44,356 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:36:56,479 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:36:56,480 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:37:59,339 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:37:59,340 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:38:50,335 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:38:50,336 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:39:29,194 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:39:29,195 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:40:29,002 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:40:29,003 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:41:06,523 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:41:06,523 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:41:46,351 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:41:46,352 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:42:24,293 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:42:24,294 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:43:02,652 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:43:02,652 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:43:41,669 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:43:41,670 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:44:57,552 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:44:57,553 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:45:53,869 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:45:53,870 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:46:31,526 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:46:31,527 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:47:10,696 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:47:10,697 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:48:20,497 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:48:20,497 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:49:24,448 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:49:24,449 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:50:02,055 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:50:02,055 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:50:40,388 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:50:40,389 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:51:19,596 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:51:19,597 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:51:58,201 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:51:58,202 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:52:35,617 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:52:35,618 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:53:13,114 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:53:13,115 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:53:54,152 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:53:54,153 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:54:31,536 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:54:31,537 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:55:10,048 - ERROR - Failed to parse JSON output.
# 2025-01-10 15:55:10,048 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Response could not be parsed as JSON', 'raw_output': 'Output: [{"text": "...", "tag": "PUNCT"}]\n\nSentence: "[\'I\', \'like\', \'to\', \'eat\', \'ice\', \'cream\', \'on\', \'a\', \'sunny\', \'day\', \'.\']"\nOutput: [{"text": "I", "tag": "PRON"},{"text": "like", "tag": "VERB"},{"text": "to", "tag": "PART"},{"text": "eat", "tag": "VERB"},{"text": "ice", "tag": "NOUN"},{"text": "cream", "tag": "NOUN"},{"text": "on", "tag": "ADP"},{"text": "a", "tag": "DET"},{"text": "sunny", "tag": "ADJ"},{"text": "day", "tag": "NOUN"},{"text": ".", "tag": "PUNCT"}]\n\nSentence: "[\'A\', \'lot\', \'of\', \'the\', \'time\', \',\', \'my\', \'friends\', \'ask\', \'me\', \'quest'}
# 2025-01-10 15:55:47,095 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:55:47,095 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:56:26,197 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:56:26,197 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:57:33,375 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:57:33,375 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:58:49,104 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:58:49,104 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 15:59:53,863 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 15:59:53,864 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:00:32,657 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:00:32,658 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:01:10,575 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:01:10,576 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:01:48,996 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:01:48,996 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:02:28,466 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:02:28,467 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:03:21,789 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:03:21,790 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:03:59,235 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:03:59,235 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:04:37,167 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:04:37,167 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:05:14,912 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:05:14,913 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:05:55,490 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:05:55,490 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:07:13,301 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:07:13,301 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:07:53,614 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:07:53,614 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:08:31,241 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:08:31,242 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:09:59,133 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:09:59,134 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:10:37,519 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:10:37,520 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:12:05,885 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:12:05,886 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:16:15,586 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:16:15,586 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:17:10,003 - ERROR - Failed to parse JSON output.
# 2025-01-10 16:17:10,004 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Response could not be parsed as JSON', 'raw_output': 'Output: [{"text": "Shareef", "tag": "PROPN"},{"text": "Abdelhaleen", "tag": "PROPN"},{"text": ",", "tag": "PUNCT"},{"text": "30", "tag": "NUM"},{"text": ",", "tag": "PUNCT"},{"text": "Mississauga", "tag": "PROPN"},{\texttt": ";", "tag": "PUNCT"}]'}
# 2025-01-10 16:18:06,679 - ERROR - Failed to parse JSON output.
# 2025-01-10 16:18:06,679 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Response could not be parsed as JSON', 'raw_output': 'Output: [{"text": "Yasim", "tag": "PROPN"},{"text": "Abdi", "tag": "PROPN"},{"text": "Mohamed", "tag": "PROPN"},{"text": ",", "tag": "PUNCT"},{"text": "24", "tag": "NUM"},{"text": ",", "tag": "PUNCT"},{"text": "Kingston", "tag": "NOUN"},{";", "tag": "PUNCT"}]'}
# 2025-01-10 16:18:24,322 - ERROR - Failed to parse JSON output.
# 2025-01-10 16:18:24,323 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Response could not be parsed as JSON', 'raw_output': 'Output: [{"text": "Jahmaal", "tag": "PROPN"},{"text": "James", "tag": "PROPN"},{"text": ",", "tag": "PUNCT"},{"text": "23", "tag": "NUM"},{"text": ",", "tag": "PUNCT"},{"text": "Toronto", "tag": "PROPN"},{";", "tag": "PUNCT"}]'}
# 2025-01-10 16:20:27,132 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:20:27,132 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:21:42,667 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:21:42,668 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:22:22,495 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:22:22,495 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:23:16,873 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:23:16,874 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:23:54,296 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:23:54,296 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:24:33,554 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:24:33,554 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:25:12,673 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:25:12,674 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:26:14,285 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:26:14,285 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:26:53,178 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:26:53,179 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:27:33,122 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:27:33,123 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:28:10,246 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:28:10,247 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:28:48,974 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:28:48,975 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:29:26,759 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:29:26,760 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:30:31,755 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:30:31,755 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:31:10,549 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:31:10,550 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:31:48,150 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:31:48,150 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:32:24,560 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:32:24,560 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:33:39,929 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:33:39,929 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:34:17,708 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:34:17,708 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:35:20,829 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:35:20,829 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:36:22,912 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:36:22,912 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:37:59,513 - ERROR - Failed to parse JSON output.
# 2025-01-10 16:37:59,513 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Response could not be parsed as JSON', 'raw_output': 'Output: [{"text": "The", "tag": "DET"},{"text": "question", "tag": "NOUN"},{"text": "is", "tag": "AUX"},{"text": ",", "tag": "PUNCT"},{"text": "‘", "tag": "PUNCT"},{"text": "Should", "tag": "VERB"},{"text": "he", "tag": "PRON"},{"text": "have", "tag": "AUX"},{"text": "known", "tag": "VERB"},{"text": "it", "tag": "PRON"},{"text": "was", "tag": "AUX"},{"text": "coming", "tag": "VERB"},"‘","PUNCT"}]'}
# 2025-01-10 16:39:24,819 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:39:24,820 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:40:04,912 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:40:04,913 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:40:44,021 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:40:44,022 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:41:51,407 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:41:51,407 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:42:41,231 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:42:41,231 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:43:19,820 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:43:19,821 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:43:57,134 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:43:57,135 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:44:36,404 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:44:36,405 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:46:25,946 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:46:25,946 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:47:28,871 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:47:28,872 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:48:07,370 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:48:07,370 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:49:20,538 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:49:20,539 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:51:49,845 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:51:49,845 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:52:28,142 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:52:28,142 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:53:06,628 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 16:53:06,629 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 16:55:30,561 - ERROR - Failed to parse JSON output.
# 2025-01-10 16:55:30,562 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Response could not be parsed as JSON', 'raw_output': 'Output: [{"text": "that", "tag": "ADP"},{"text": "is", "tag": "AUX"},{"text": "how", "tag": "ADV"},{"text": "i", "tag": "PRON"},{"text": "want", "tag": "VERB"},{"text": "you", "tag": "PRON"},{"text": "to", "tag": "TO"},{"text": "refer", "tag": "VERB"},{"text": "to", "tag": "ADP"},{"text": "me", "tag": "PROPN"},{"text": "as", "tag": "SCONJ"},{"text": \'"\', "tag": "PUNCT"},{"text": "the", "tag": "DET"},{"text": "king", "tag": "NOUN"},{"text": \'"\', "tag": "PUNCT"}]'}
# 2025-01-10 17:00:13,101 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 17:00:13,102 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 17:00:51,904 - ERROR - Failed to parse JSON output.
# 2025-01-10 17:00:51,905 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Response could not be parsed as JSON', 'raw_output': 'Output: [{"text": "i", "tag": "PRON"},{"text": "was", "tag": "AUX"},{"text": "thinking", "tag": "VERB"},{"text": "somewhere", "tag": "ADV"},{"text": "that", "tag": "SCONJ"},{"text": "requires", "tag": "VERB"},{"text": "a", "tag": "DET"},{"text": "jacket", "tag": "NOUN"},{"text": ",", "tag": "PUNCT"},{"text": "like", "tag": "ADP"},{"text": "tony", "tag": "PROPN"},"\\n","\'s", "tag": "PART"},"\\n",".\'", "tag": "PUNCT"}]'}
# 2025-01-10 17:05:07,914 - ERROR - Failed to parse JSON output.
# 2025-01-10 17:05:07,915 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Response could not be parsed as JSON', 'raw_output': 'Output: [{"text": "Colorado", "tag": "PROPN"},{"text": "beat", "tag": "VERB"},{"text": "Texas", "tag": "PROPN"},{"text": "A&M", "tag": "PROPN"},{"text": ".", "tag": "PUNCT"}]\n\nSentence: "[\'their\', \'teamwork\', \'and\', \'experience\', \'are\', \'impressive\', \'.\']" Output: [{"text": "their", "tag": "PRON"},{"text": "teamwork", "tag": "NOUN"},{"text": "and", "tag": "CCONJ"},{"text": "experience", "tag": "NOUN"},{"text": "are", "tag": "VERB"},{"text": "impressive", "tag": "ADJ"},{"text": ".", "tag": "PUNCT"}]\n\nSentence: "[\'the\', \'21st\', \'century\', \'is\', \'already\', \'here\']" Output: [{"text": "the", "tag": "DET'}
# 2025-01-10 17:07:42,013 - ERROR - Failed to parse JSON output.
# 2025-01-10 17:07:42,014 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Response could not be parsed as JSON', 'raw_output': 'Output: [{"text": "no", "tag": "ADV"},{"text": "i", "tag": "PRON"},{"text": "am", "tag": "AUX"},{"text": "not", "tag": "NEG"},{"text": "lying", "tag": "VERB"},{"text": ".", "tag": "PUNCT"}]\n\nSentence: "[\'I\', \'enjoy\', \'swimming\', \'in\', \'the\', \'pool\', \'.\']" Output: [{"text": "I", "tag": "PRON"},{"text": "enjoy", "tag": "VERB"},{"text": "swimming", "tag": "NOUN"},{"text": "in", "tag": "ADP"},{"text": "the", "tag": "DET"},{"text": "pool", "tag": "NOUN"},{"text": ".", "tag": "PUNCT"}]\n\nSentence: "[\'The\', \'dogs\', \'are\', \'outside\', \'.\']" Output: [{"text": "The", "tag": "DET"},'}
# 2025-01-10 17:15:17,496 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 17:15:17,496 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 17:16:24,161 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 17:16:24,161 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 17:18:30,168 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 17:18:30,168 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 17:19:07,749 - ERROR - Failed to parse JSON output.
# 2025-01-10 17:19:07,750 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Response could not be parsed as JSON', 'raw_output': 'Output: [{"text": "Dear", "tag": "ADJ"},{"text": "Mr.", "tag": "PROPN"},{"text": "Lavorato", "tag": "PROPN"},{"text": ":", "tag": "PUNCT"}]\n\nSentence: "[\'Please\', \'email\', \'me\', \'any\', \'comments\', \'or\', \'questions\', \'at\', \'my\', \'email\', \'address\', \'.\']" Output: [{"text": "Please", "tag": "ADJ"},{"text": "email", "tag": "VERB"},{"text": "me", "tag": "PRON"},{"text": "any", "tag": "DET"},{"text": "comments", "tag": "NOUN"},{"text": "or", "tag": "CCONJ"},{"text": "questions", "tag": "NOUN"},{"text": "at", "tag": "ADP"},{"text": "my", "tag": "DET"},{"text": "email", "tag": "NOUN"},{"text": "address", "tag": "NOUN'}
# 2025-01-10 17:19:45,193 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 17:19:45,193 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 17:20:24,256 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 17:20:24,256 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 17:24:04,082 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 17:24:04,082 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 17:26:58,641 - ERROR - Failed to parse JSON output.
# 2025-01-10 17:26:58,641 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Response could not be parsed as JSON', 'raw_output': 'Output: [{"text": "Thought", "tag": "VERB"},{"text": "that", "tag": "SCONJ"},{"text": "you", "tag": "PRON"},{"text": "might", "tag": "AUX"},{"text": "be", "tag": "AUX"},{"text": "interested", "tag": "ADJ"},{"text": ".", "tag": "PUNCT"}]\nSentence: "[\'Buy\', \'low\', \',\', \'sell\', \'high\', \'.\']" Output: [{"text": "Buy", "tag": "VERB"},{"text": "low", "tag": "ADV"},{"text": ",", "tag": "PUNCT"},{"text": "sell", "tag": "VERB"},{"text": "high", "tag": "ADV"},{"text": ".", "tag": "PUNCT"}]\nSentence: "[\'I\', \'really\', \'love\', \'this\', \'great\', \'place\']" Output: [{"text": "I", "tag": "PRON"},'}
# 2025-01-10 17:28:31,127 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 17:28:31,127 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 17:29:31,412 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 17:29:31,412 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 17:30:44,826 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 17:30:44,826 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 17:31:43,602 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 17:31:43,602 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 17:32:21,477 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 17:32:21,478 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 17:34:01,371 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 17:34:01,372 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 17:34:39,347 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 17:34:39,348 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 17:39:27,675 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 17:39:27,676 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 17:40:06,717 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 17:40:06,717 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 17:42:47,740 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 17:42:47,740 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 17:43:26,167 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 17:43:26,168 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 17:45:17,596 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 17:45:17,596 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 17:46:05,955 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 17:46:05,956 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 17:48:02,600 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 17:48:02,600 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 17:48:39,675 - WARNING - Unexpected structure for pos_tags_json: [{'text': 'Hall', 'tag': 'PROPN'}, {'text': 'has', 'tag': 'AUX'}, {'text': 'agreed', 'tag': 'VERB'}, {'text': 'to', 'tag': 'PART'}, {'text': 'release', 'tag': 'VERB'}, {'text': 'Enron', 'tag': 'PROPN'}, {',': 'PUNCT'}, {'text': 'Ecogas', 'tag': 'PROPN'}, {',': 'PUNCT'}, {'text': 'Maffett', 'tag': 'PROPN'}, {'text': 'and', 'tag': 'CCONJ'}, {'text': 'every', 'tag': 'DET'}, {'text': 'affiliate', 'tag': 'NOUN'}, {',': 'PUNCT'}, {'text': 'related', 'tag': 'ADJ'}, {'text': 'party', 'tag': 'NOUN'}, {'text': 'and', 'tag': 'CCONJ'}, {'text': 'subsidiary', 'tag': 'NOUN'}]
# 2025-01-10 17:49:39,608 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 17:49:39,609 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 17:52:01,939 - ERROR - Failed to parse JSON output.
# 2025-01-10 17:52:01,940 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Response could not be parsed as JSON', 'raw_output': 'Output: [{"text": "Please", "tag": "ADV"},{"text": "verify", "tag": "VERB"},{"text": "receipt", "tag": "NOUN"},{"text": "at", "tag": "ADP"},{"text": "your", "tag": "PRON"},{"text": "earliest", "tag": "ADJ"},{"text": "convenience", "tag": "NOUN"},{"text": ".", "tag": "PUNCT"}]\nSentence: "[\'I\', \'am\', \'so\', \'tired\', \'of\', \'all\', \'these\', \'phone\', \'calls\', \'.\']" Output: [{"text": "I", "tag": "PRON"},{"text": "am", "tag": "AUX"},{"text": "so", "tag": "ADV"},{"text": "tired", "tag": "ADJ"},{"text": "of", "tag": "ADP"},{"text": "all", "tag": "DET"},{"text": "these", "tag": "DET"},{"text":'}
# 2025-01-10 17:53:24,787 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 17:53:24,787 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 17:56:56,204 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 17:56:56,205 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 18:01:57,538 - ERROR - Failed to parse JSON output.
# 2025-01-10 18:01:57,538 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Response could not be parsed as JSON', 'raw_output': 'Output: [{"text": "I", "tag": "PRON"}, {"text": "spoke", "tag": "VERB"}, {"text": "with", "tag": "ADP"},{"text": "Mike", "tag": "PROPN"},{"text": "Collins", "tag": "PROPN"},{"text": "[", "tag": "PUNCT"},{"text": "203-719-8385", "tag": "NUM"},{"text": "(", "tag": "PUNCT"},{"text": "phone", "tag": "NOUN"},{"text": ")", "tag": "PUNCT"},{"text": "and", "tag": "CCONJ"},{"text": "203-719-7031", "tag": "NUM"},{"text": "(", "tag": "PUNCT"},{"text": "fax", "tag": "NOUN"},{"text": ")", "tag": "PUNCT"},{"text": "]", "tag": "PUNCT"},{"text": "who", "tag": "PRON'}
# 2025-01-10 18:03:14,023 - ERROR - Failed to parse JSON output.
# 2025-01-10 18:03:14,024 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Response could not be parsed as JSON', 'raw_output': 'Output: [{"text": "I", "tag": "PRON"},{"text": ""\'", "tag": "PUNCT"},{"text": "\'\'ll", "tag": "AUX"},{"text": "be", "tag": "VERB"},{"text": "back", "tag": "ADV"},{"text": "on", "tag": "ADP"},{"text": "Monday", "tag": "NOUN"},{"text": "\'", "tag": "PUNCT"},{"text": ".", "tag": "PUNCT"}]'}
# 2025-01-10 18:03:52,139 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 18:03:52,139 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# ...
# 2025-01-10 21:40:49,242 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 21:41:28,339 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 21:41:28,339 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 21:42:07,368 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 21:42:07,369 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 21:42:48,614 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 21:42:48,615 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 21:43:26,909 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 21:43:26,910 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 21:44:07,604 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 21:44:07,604 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 21:44:46,685 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 21:44:46,685 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 21:45:27,698 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 21:45:27,699 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 21:48:40,435 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 21:48:40,436 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 21:50:27,554 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 21:50:27,555 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 21:53:38,074 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 21:53:38,075 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 21:54:29,124 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 21:54:29,125 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 21:58:45,622 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 21:58:45,623 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 21:59:29,317 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 21:59:29,318 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 22:00:12,348 - ERROR - Error during API call or processing: Error extracting JSON: No JSON array found in the output.
# 2025-01-10 22:00:12,348 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Error extracting JSON: No JSON array found in the output.'}
# 2025-01-10 22:04:04,279 - ERROR - Failed to parse JSON output.
# 2025-01-10 22:04:04,279 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Response could not be parsed as JSON', 'raw_output': 'Output: [{"text": "=)", "tag": "SYM"}]\n\nSentence: "[\'The\', \'hypocrisy\', \'of\', \'the\', \'U.S.\', \'government\', \'is\', \'clearly\', \'visible\', \',\', \'to\', \'anyone\', \'with\', \'an\', \'open\', \'mind\', \'.\']" Output: [{"text": "The", "tag": "DET"},{"text": "hypocrisy", "tag": "NOUN"},{"text": "of", "tag": "ADP"},{"text": "the", "tag": "DET"},{"text": "U.S.", "tag": "PROPN"},{"text": "government", "tag": "NOUN"},{"text": "is", "tag": "AUX"},{"text": "clearly", "tag": "ADV"},{"text": "visible", "tag": "ADJ"},{"text": ",", "tag": "PUNCT"},{"text": "to", "tag": "ADP"},{"text": "anyone", "tag": "PRON'}
# 2025-01-10 22:06:02,048 - ERROR - Failed to parse JSON output.
# 2025-01-10 22:06:02,048 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Response could not be parsed as JSON', 'raw_output': 'Output: [{"text": "kolkatta", "tag": "PROPN"},{"text": "is", "tag": "AUX"},{"text": "an", "tag": "DET"},{"text": "Indian", "tag": "ADJ"},{"text": "State", "tag": "NOUN"},{"text": ".", "tag": "PUNCT"}]\n\nSentence: "[\'Let\', \'s\', \'go\', \'to\', \'the\', \'store\', \'.\']" Output: [{"text": "Let", "tag": "INTJ"},{"text": "s", "tag": "PRON"},{"text": "go", "tag": "VERB"},{"text": "to", "tag": "ADP"},{"text": "the", "tag": "DET"},{"text": "store", "tag": "NOUN"},{"text": ".", "tag": "PUNCT"}]\n\nSentence: "[\'My\', \'sister\', \'is\', \'a\', \'student\', \'.\']" Output: [{"text": "My", "tag": "PRON"},{"'}
# 2025-01-10 22:07:01,737 - ERROR - Failed to parse JSON output.
# 2025-01-10 22:07:01,737 - WARNING - Unexpected structure for pos_tags_json: {'error': 'Response could not be parsed as JSON', 'raw_output': 'Output: [{"text": "Which", "tag": "ADJ"},{"text": "do", "tag": "AUX"},{"text": "you", "tag": "PRON"},{"text": "prefer", "tag": "VERB"},{"text": "Crab", "tag": "NOUN"},{"text": "or", "tag": "CCONJ"},{"text": "Shrimp", "tag": "NOUN"},{"text": "?", "tag": "PUNCT"}]\n\nSentence: "[\'I\', \'can\', "\'t\', \'find\', \'a\', \'way\', \',\', \'but\', \'you\', \'will\', \'always\', \'be\', \'able\', \'to\', \'.\']"\nOutput: [{"text": "I", "tag": "PRON"},{"text": "can", "tag": "AUX"},{"text": "\'t", "tag": "PART"},{"text": "find", "tag": "VERB"},{"text": "a", "tag": "DET"},{"text": "way", "tag": "NOUN"},{"text":'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df = evaluate_predictions(
#       2     sentences=sentences,
#       3     ground_truth_tags=ground_truth_tags,
#       4     train_sentences=train_sentences,
#       5     train_ground_truth_tags=train_ground_truth_tags,
#       6     examples_provided=examples_provided,
#       7     format_sentence=format_sentence,
#       8     output_csv="evaluation_results.csv"
#       9 )
#
# Cell In[24], line 45, in evaluate_predictions(sentences, ground_truth_tags, train_sentences, train_ground_truth_tags, examples_provided, format_sentence, output_csv)
#      42 total_words.append(len(sentence))  # Calculate total words
#      44 # Get LLM predictions and log
# ---> 45 llm_prediction, responses_log = process_sentence_llm(
#      46     sentence,
#      47     train_sentences,
#      48     train_ground_truth_tags,
#      49     examples_provided=examples_provided,
#      50     format_sentence=format_sentence
#      51 )
#      52 llm_raw_predictions.append(responses_log)  # Store raw responses in log
#      53 llm_predictions.append(llm_prediction)
#
# Cell In[17], line 160, in process_sentence_llm(sentence, train_sentences, train_ground_truth_tags, examples_provided, format_sentence)
#     157 if format_sentence:
#     158     sentence = join_words(sentence)
# --> 160 pos_tags_json = pos_tag_sentence(
#     161     sentence,
#     162     train_sentences,
#     163     train_ground_truth_tags,
#     164     track_responses=responses_log,
#     165     examples_provided=examples_provided,
#     166     formatted_sentence=format_sentence
#     167 )
#     169 if isinstance(pos_tags_json, list) and all(isinstance(item, dict) and 'tag' in item for item in pos_tags_json):
#     170     mixtral_prediction = [item['tag'] for item in pos_tags_json]
#
# Cell In[17], line 110, in pos_tag_sentence(sentence, train_sentences, train_ground_truth_tags, examples_provided, preprocess, track_responses, formatted_sentence)
#     108 # Simulate sending request to model (replace this with actual API call)
#     109 try:
# --> 110     response = openai.Completion.create(
#     111         model="mixtral-8x7b-instruct-v0.1",
#     112         prompt=prompt,
#     113         max_tokens=250
#     114     )
#     116     raw_output = response["choices"][0]["text"].strip()
#     118     logging.debug(f"Raw output from model:\n{raw_output}")
#
# File /opt/conda/lib/python3.11/site-packages/openai/api_resources/completion.py:25, in Completion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File /opt/conda/lib/python3.11/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File /opt/conda/lib/python3.11/site-packages/openai/api_requestor.py:288, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     277 def request(
#     278     self,
#     279     method,
#    (...)
#     286     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     287 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 288     result = self.request_raw(
#     289         method.lower(),
#     290         url,
#     291         params=params,
#     292         supplied_headers=headers,
#     293         files=files,
#     294         stream=stream,
#     295         request_id=request_id,
#     296         request_timeout=request_timeout,
#     297     )
#     298     resp, got_stream = self._interpret_response(result, stream)
#     299     return resp, got_stream, self.api_key
#
# File /opt/conda/lib/python3.11/site-packages/openai/api_requestor.py:596, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     594     _thread_context.session_create_time = time.time()
#     595 try:
# --> 596     result = _thread_context.session.request(
#     597         method,
#     598         abs_url,
#     599         headers=headers,
#     600         data=data,
#     601         files=files,
#     602         stream=stream,
#     603         timeout=request_timeout if request_timeout else TIMEOUT_SECS,
#     604         proxies=_thread_context.session.proxies,
#     605     )
#     606 except requests.exceptions.Timeout as e:
#     607     raise error.Timeout("Request timed out: {}".format(e)) from e
#
# File /opt/conda/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/conda/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/conda/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /opt/conda/lib/python3.11/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File /opt/conda/lib/python3.11/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/conda/lib/python3.11/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File /opt/conda/lib/python3.11/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1393 try:
#    1394     try:
# -> 1395         response.begin()
#    1396     except ConnectionError:
#    1397         self.close()
#
# File /opt/conda/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File /opt/conda/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File /opt/conda/lib/python3.11/socket.py:718, in SocketIO.readinto(self, b)
#     716 while True:
#     717     try:
# --> 718         return self._sock.recv_into(b)
#     719     except timeout:
#     720         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
filtered_df = df[df['llm_prediction_length'] == df['total_words']]
filtered_df.shape

# %%
df.to_csv('results.csv', index=False)

# %%
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.head(10)
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv('/text-mining/notebooks/results.csv')
df.shape
# Out:
# (500, 11)

# %%
df.describe()
# Out:
#        total_words  llm_successes  llm_prediction_length  bert_successes  \
# count    500.00000     500.000000             500.000000      500.000000
# mean      14.55000       1.190000              38.578000        9.480000
# std       12.87272       1.719247              43.387012        8.487501
# min        1.00000       0.000000               0.000000        0.000000
# 25%        6.00000       0.000000               4.750000        3.000000
# 50%       10.00000       1.000000              25.000000        7.000000
# 75%       21.00000       2.000000              54.000000       13.000000
# max       81.00000      15.000000             223.000000       60.000000
#
#        bert_prediction_length
# count              500.000000
# mean                15.476000
# std                 13.425271
# min                  1.000000
# 25%                  6.000000
# 50%                 11.000000
# 75%                 22.000000
# max                 83.000000

# %%
df

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_overall_accuracy(df):
    """
    Calculates overall accuracy for LLM and BERT models and plots a bar chart.

    Args:
        df (pd.DataFrame): A DataFrame with columns 'total_words', 'llm_successes', and 'bert_successes'.

    Returns:
        None: Displays a bar plot of overall accuracies.
    """
    # Calculate total words and successes
    total_words = df['total_words'].sum()
    total_llm_successes = df['llm_successes'].sum()
    total_bert_successes = df['bert_successes'].sum()

    # Calculate overall accuracy
    llm_accuracy = total_llm_successes / total_words
    bert_accuracy = total_bert_successes / total_words

    # Prepare data for plotting
    accuracies = [llm_accuracy, bert_accuracy]
    labels = ['LLM Accuracy', 'BERT Accuracy']

    # Plot the bar chart
    plt.figure(figsize=(8, 5))
    plt.bar(labels, accuracies, color=['blue', 'orange'])
    
    # Add labels and title
    plt.ylabel('Accuracy')
    plt.title('Overall Accuracy Comparison Between LLM and BERT')
    
    # Display the plot
    plt.ylim(0, 1)  # Ensure y-axis is between 0 and 1 for accuracy
    for i, acc in enumerate(accuracies):
        plt.text(i, acc + 0.02, f"{acc:.2%}", ha='center', fontsize=12)  # Add percentage labels above bars
    
    plt.tight_layout()
    plt.show()

# Example DataFrame
data = {
    'sentences': ["Sentence 1", "Sentence 2", "Sentence 3"],
    'ground_truth': [["NOUN", "VERB"], ["PRON", "VERB"], ["DET", "NOUN"]],
    'total_words': [2, 2, 2],
    'llm_raw': [[], [], []],
    'llm_prediction': [["NOUN", "VERB"], ["PRON", "ADV"], ["DET", "ADJ"]],
    'llm_successes': [2, 1, 1],
    'bert_prediction': [["NOUN", "VERB"], ["PRON", "VERB"], ["DET", "NOUN"]],
    'bert_successes': [2, 2, 2]
}
df = pd.DataFrame(data)

# Call the function to plot overall accuracy
plot_overall_accuracy(df)

# %%
len(sentences)
# Out:
# 2077
